# %%
import os
import glob
import numpy as np
import torch
from torch.utils.data import Dataset, DataLoader
import torch.nn as nn
import torch.nn.functional as F
from tqdm import tqdm
import matplotlib.pyplot as plt

# %%
DATA_ROOT = "data"  # change to your dataset root
TRAIN_DIR = os.path.join(DATA_ROOT, "train")
VAL_DIR = os.path.join(DATA_ROOT, "val")
CACHE_TO_NPY = False  # set True to create .npy cache copies for faster I/O
DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Device:", DEVICE)
# Out:
# Device: cuda

# %%
try:
    import rasterio
    from rasterio.enums import Resampling

    def read_tif(path):
        with rasterio.open(path) as src:
            arr = src.read().astype(np.float32)  # shape (bands, H, W)
        return arr

    print("Using rasterio for TIFF reading")
except Exception as e:
    print("rasterio not available (or failed). Falling back to tifffile. Error:", e)
    import tifffile

    def read_tif(path):
        arr = tifffile.imread(path).astype(np.float32)
        # tifffile often returns (H,W,bands) or (bands,H,W)
        if arr.ndim == 3 and arr.shape[-1] == 12 and arr.shape[0] != 12:
            arr = np.transpose(arr, (2, 0, 1))
        elif arr.ndim == 2:
            arr = arr[np.newaxis, ...]
        elif arr.ndim == 3 and arr.shape[0] == 12:
            pass
        else:
            # try to be permissive
            arr = np.transpose(arr, (2, 0, 1)) if arr.shape[-1] <= 64 else arr
        return arr
# Out:
# Using rasterio for TIFF reading

# %%
def read_mask(path):
    # use rasterio if available, else tifffile
    try:
        if "rasterio" in globals():
            with rasterio.open(path) as src:
                m = src.read(1).astype(np.uint8)
        else:
            m = tifffile.imread(path).astype(np.uint8)
    except Exception:
        # fallback to imageio
        import imageio

        m = imageio.imread(path).astype(np.uint8)
    # ensure binary 0/1
    m = (m > 0).astype(np.uint8)
    return m

# %%
import os, glob

def find_pairs(data_dir, img_dir="images", mask_dir="labels", img_ext=".tif", mask_ext=".png"):
    """
    Finds image–mask pairs when images are in images/ and masks in labels/.
    Matches by numeric basename (e.g., 0.tif <-> 0.png).
    """
    img_paths = glob.glob(os.path.join(data_dir, img_dir, f"*{img_ext}"))
    x, y = [], []

    print(f"Found {len(img_paths)} image files in {os.path.join(data_dir, img_dir)}")

    for img_path in img_paths:
        base = os.path.splitext(os.path.basename(img_path))[0]  # e.g. "0"
        mask_path = os.path.join(data_dir, mask_dir, base + mask_ext)
        if os.path.exists(mask_path):
            x.append(img_path)
            y.append(mask_path)
            print(f"✅ Pair: {img_path} <-> {mask_path}")
        else:
            print(f"⚠️ No mask found for {img_path}")

    print(f"Total pairs in {data_dir}: {len(x)}")
    return x, y


# usage
TRAIN_DIR = r"data/train"
VAL_DIR   = r"data/val"

x_train, y_train = find_pairs(TRAIN_DIR)
x_val, y_val = find_pairs(VAL_DIR)
# Out:
# Found 244 image files in data/train\images
# ✅ Pair: data/train\images\0.tif <-> data/train\labels\0.png
# ✅ Pair: data/train\images\1.tif <-> data/train\labels\1.png
# ✅ Pair: data/train\images\10.tif <-> data/train\labels\10.png
# ✅ Pair: data/train\images\101.tif <-> data/train\labels\101.png
# ✅ Pair: data/train\images\102.tif <-> data/train\labels\102.png
# ✅ Pair: data/train\images\103.tif <-> data/train\labels\103.png
# ✅ Pair: data/train\images\104.tif <-> data/train\labels\104.png
# ✅ Pair: data/train\images\105.tif <-> data/train\labels\105.png
# ✅ Pair: data/train\images\106.tif <-> data/train\labels\106.png
# ✅ Pair: data/train\images\107.tif <-> data/train\labels\107.png
# ✅ Pair: data/train\images\108.tif <-> data/train\labels\108.png
# ✅ Pair: data/train\images\110.tif <-> data/train\labels\110.png
# ✅ Pair: data/train\images\113.tif <-> data/train\labels\113.png
# ✅ Pair: data/train\images\114.tif <-> data/train\labels\114.png
# ✅ Pair: data/train\images\115.tif <-> data/train\labels\115.png
# ✅ Pair: data/train\images\117.tif <-> data/train\labels\117.png
# ✅ Pair: data/train\images\12.tif <-> data/train\labels\12.png
# ✅ Pair: data/train\images\121.tif <-> data/train\labels\121.png
# ✅ Pair: data/train\images\122.tif <-> data/train\labels\122.png
# ✅ Pair: data/train\images\123.tif <-> data/train\labels\123.png
# ✅ Pair: data/train\images\124.tif <-> data/train\labels\124.png
# ✅ Pair: data/train\images\125.tif <-> data/train\labels\125.png
# ✅ Pair: data/train\images\126.tif <-> data/train\labels\126.png
# ✅ Pair: data/train\images\127.tif <-> data/train\labels\127.png
# ✅ Pair: data/train\images\128.tif <-> data/train\labels\128.png
# ✅ Pair: data/train\images\129.tif <-> data/train\labels\129.png
# ✅ Pair: data/train\images\130.tif <-> data/train\labels\130.png
# ✅ Pair: data/train\images\131.tif <-> data/train\labels\131.png
# ✅ Pair: data/train\images\132.tif <-> data/train\labels\132.png
# ✅ Pair: data/train\images\133.tif <-> data/train\labels\133.png
# ✅ Pair: data/train\images\135.tif <-> data/train\labels\135.png
# ✅ Pair: data/train\images\136.tif <-> data/train\labels\136.png
# ✅ Pair: data/train\images\137.tif <-> data/train\labels\137.png
# ✅ Pair: data/train\images\139.tif <-> data/train\labels\139.png
# ✅ Pair: data/train\images\14.tif <-> data/train\labels\14.png
# ✅ Pair: data/train\images\141.tif <-> data/train\labels\141.png
# ✅ Pair: data/train\images\143.tif <-> data/train\labels\143.png
# ✅ Pair: data/train\images\144.tif <-> data/train\labels\144.png
# ✅ Pair: data/train\images\146.tif <-> data/train\labels\146.png
# ✅ Pair: data/train\images\147.tif <-> data/train\labels\147.png
# ✅ Pair: data/train\images\148.tif <-> data/train\labels\148.png
# ✅ Pair: data/train\images\149.tif <-> data/train\labels\149.png
# ✅ Pair: data/train\images\150.tif <-> data/train\labels\150.png
# ✅ Pair: data/train\images\152.tif <-> data/train\labels\152.png
# ✅ Pair: data/train\images\153.tif <-> data/train\labels\153.png
# ✅ Pair: data/train\images\154.tif <-> data/train\labels\154.png
# ✅ Pair: data/train\images\156.tif <-> data/train\labels\156.png
# ✅ Pair: data/train\images\157.tif <-> data/train\labels\157.png
# ✅ Pair: data/train\images\158.tif <-> data/train\labels\158.png
# ✅ Pair: data/train\images\159.tif <-> data/train\labels\159.png
# ✅ Pair: data/train\images\16.tif <-> data/train\labels\16.png
# ✅ Pair: data/train\images\160.tif <-> data/train\labels\160.png
# ✅ Pair: data/train\images\161.tif <-> data/train\labels\161.png
# ✅ Pair: data/train\images\163.tif <-> data/train\labels\163.png
# ✅ Pair: data/train\images\164.tif <-> data/train\labels\164.png
# ✅ Pair: data/train\images\165.tif <-> data/train\labels\165.png
# ✅ Pair: data/train\images\166.tif <-> data/train\labels\166.png
# ✅ Pair: data/train\images\167.tif <-> data/train\labels\167.png
# ✅ Pair: data/train\images\168.tif <-> data/train\labels\168.png
# ✅ Pair: data/train\images\169.tif <-> data/train\labels\169.png
# ✅ Pair: data/train\images\170.tif <-> data/train\labels\170.png
# ✅ Pair: data/train\images\172.tif <-> data/train\labels\172.png
# ✅ Pair: data/train\images\173.tif <-> data/train\labels\173.png
# ✅ Pair: data/train\images\174.tif <-> data/train\labels\174.png
# ✅ Pair: data/train\images\175.tif <-> data/train\labels\175.png
# ✅ Pair: data/train\images\176.tif <-> data/train\labels\176.png
# ✅ Pair: data/train\images\177.tif <-> data/train\labels\177.png
# ✅ Pair: data/train\images\178.tif <-> data/train\labels\178.png
# ✅ Pair: data/train\images\179.tif <-> data/train\labels\179.png
# ✅ Pair: data/train\images\18.tif <-> data/train\labels\18.png
# ✅ Pair: data/train\images\180.tif <-> data/train\labels\180.png
# ✅ Pair: data/train\images\181.tif <-> data/train\labels\181.png
# ✅ Pair: data/train\images\182.tif <-> data/train\labels\182.png
# ✅ Pair: data/train\images\183.tif <-> data/train\labels\183.png
# ✅ Pair: data/train\images\184.tif <-> data/train\labels\184.png
# ✅ Pair: data/train\images\185.tif <-> data/train\labels\185.png
# ✅ Pair: data/train\images\188.tif <-> data/train\labels\188.png
# ✅ Pair: data/train\images\189.tif <-> data/train\labels\189.png
# ✅ Pair: data/train\images\190.tif <-> data/train\labels\190.png
# ✅ Pair: data/train\images\191.tif <-> data/train\labels\191.png
# ✅ Pair: data/train\images\192.tif <-> data/train\labels\192.png
# ✅ Pair: data/train\images\193.tif <-> data/train\labels\193.png
# ✅ Pair: data/train\images\194.tif <-> data/train\labels\194.png
# ✅ Pair: data/train\images\195.tif <-> data/train\labels\195.png
# ✅ Pair: data/train\images\196.tif <-> data/train\labels\196.png
# ✅ Pair: data/train\images\197.tif <-> data/train\labels\197.png
# ✅ Pair: data/train\images\20.tif <-> data/train\labels\20.png
# ✅ Pair: data/train\images\201.tif <-> data/train\labels\201.png
# ✅ Pair: data/train\images\203.tif <-> data/train\labels\203.png
# ✅ Pair: data/train\images\204.tif <-> data/train\labels\204.png
# ✅ Pair: data/train\images\206.tif <-> data/train\labels\206.png
# ✅ Pair: data/train\images\207.tif <-> data/train\labels\207.png
# ✅ Pair: data/train\images\208.tif <-> data/train\labels\208.png
# ✅ Pair: data/train\images\209.tif <-> data/train\labels\209.png
# ✅ Pair: data/train\images\21.tif <-> data/train\labels\21.png
# ✅ Pair: data/train\images\211.tif <-> data/train\labels\211.png
# ✅ Pair: data/train\images\212.tif <-> data/train\labels\212.png
# ✅ Pair: data/train\images\213.tif <-> data/train\labels\213.png
# ✅ Pair: data/train\images\214.tif <-> data/train\labels\214.png
# ✅ Pair: data/train\images\215.tif <-> data/train\labels\215.png
# ✅ Pair: data/train\images\216.tif <-> data/train\labels\216.png
# ✅ Pair: data/train\images\217.tif <-> data/train\labels\217.png
# ✅ Pair: data/train\images\218.tif <-> data/train\labels\218.png
# ✅ Pair: data/train\images\219.tif <-> data/train\labels\219.png
# ✅ Pair: data/train\images\220.tif <-> data/train\labels\220.png
# ✅ Pair: data/train\images\221.tif <-> data/train\labels\221.png
# ✅ Pair: data/train\images\222.tif <-> data/train\labels\222.png
# ✅ Pair: data/train\images\223.tif <-> data/train\labels\223.png
# ✅ Pair: data/train\images\225.tif <-> data/train\labels\225.png
# ✅ Pair: data/train\images\227.tif <-> data/train\labels\227.png
# ✅ Pair: data/train\images\228.tif <-> data/train\labels\228.png
# ✅ Pair: data/train\images\229.tif <-> data/train\labels\229.png
# ✅ Pair: data/train\images\23.tif <-> data/train\labels\23.png
# ✅ Pair: data/train\images\230.tif <-> data/train\labels\230.png
# ✅ Pair: data/train\images\232.tif <-> data/train\labels\232.png
# ✅ Pair: data/train\images\234.tif <-> data/train\labels\234.png
# ✅ Pair: data/train\images\235.tif <-> data/train\labels\235.png
# ✅ Pair: data/train\images\236.tif <-> data/train\labels\236.png
# ✅ Pair: data/train\images\237.tif <-> data/train\labels\237.png
# ✅ Pair: data/train\images\238.tif <-> data/train\labels\238.png
# ✅ Pair: data/train\images\239.tif <-> data/train\labels\239.png
# ✅ Pair: data/train\images\24.tif <-> data/train\labels\24.png
# ✅ Pair: data/train\images\240.tif <-> data/train\labels\240.png
# ✅ Pair: data/train\images\241.tif <-> data/train\labels\241.png
# ✅ Pair: data/train\images\242.tif <-> data/train\labels\242.png
# ✅ Pair: data/train\images\243.tif <-> data/train\labels\243.png
# ✅ Pair: data/train\images\245.tif <-> data/train\labels\245.png
# ✅ Pair: data/train\images\246.tif <-> data/train\labels\246.png
# ✅ Pair: data/train\images\247.tif <-> data/train\labels\247.png
# ✅ Pair: data/train\images\248.tif <-> data/train\labels\248.png
# ✅ Pair: data/train\images\249.tif <-> data/train\labels\249.png
# ✅ Pair: data/train\images\25.tif <-> data/train\labels\25.png
# ✅ Pair: data/train\images\250.tif <-> data/train\labels\250.png
# ✅ Pair: data/train\images\251.tif <-> data/train\labels\251.png
# ✅ Pair: data/train\images\252.tif <-> data/train\labels\252.png
# ✅ Pair: data/train\images\254.tif <-> data/train\labels\254.png
# ✅ Pair: data/train\images\256.tif <-> data/train\labels\256.png
# ✅ Pair: data/train\images\258.tif <-> data/train\labels\258.png
# ✅ Pair: data/train\images\259.tif <-> data/train\labels\259.png
# ✅ Pair: data/train\images\26.tif <-> data/train\labels\26.png
# ✅ Pair: data/train\images\260.tif <-> data/train\labels\260.png
# ✅ Pair: data/train\images\261.tif <-> data/train\labels\261.png
# ✅ Pair: data/train\images\262.tif <-> data/train\labels\262.png
# ✅ Pair: data/train\images\264.tif <-> data/train\labels\264.png
# ✅ Pair: data/train\images\266.tif <-> data/train\labels\266.png
# ✅ Pair: data/train\images\267.tif <-> data/train\labels\267.png
# ✅ Pair: data/train\images\268.tif <-> data/train\labels\268.png
# ✅ Pair: data/train\images\269.tif <-> data/train\labels\269.png
# ✅ Pair: data/train\images\27.tif <-> data/train\labels\27.png
# ✅ Pair: data/train\images\270.tif <-> data/train\labels\270.png
# ✅ Pair: data/train\images\271.tif <-> data/train\labels\271.png
# ✅ Pair: data/train\images\274.tif <-> data/train\labels\274.png
# ✅ Pair: data/train\images\275.tif <-> data/train\labels\275.png
# ✅ Pair: data/train\images\276.tif <-> data/train\labels\276.png
# ✅ Pair: data/train\images\277.tif <-> data/train\labels\277.png
# ✅ Pair: data/train\images\278.tif <-> data/train\labels\278.png
# ✅ Pair: data/train\images\279.tif <-> data/train\labels\279.png
# ✅ Pair: data/train\images\28.tif <-> data/train\labels\28.png
# ✅ Pair: data/train\images\280.tif <-> data/train\labels\280.png
# ✅ Pair: data/train\images\281.tif <-> data/train\labels\281.png
# ✅ Pair: data/train\images\282.tif <-> data/train\labels\282.png
# ✅ Pair: data/train\images\283.tif <-> data/train\labels\283.png
# ✅ Pair: data/train\images\284.tif <-> data/train\labels\284.png
# ✅ Pair: data/train\images\285.tif <-> data/train\labels\285.png
# ✅ Pair: data/train\images\286.tif <-> data/train\labels\286.png
# ✅ Pair: data/train\images\287.tif <-> data/train\labels\287.png
# ✅ Pair: data/train\images\288.tif <-> data/train\labels\288.png
# ✅ Pair: data/train\images\289.tif <-> data/train\labels\289.png
# ✅ Pair: data/train\images\29.tif <-> data/train\labels\29.png
# ✅ Pair: data/train\images\292.tif <-> data/train\labels\292.png
# ✅ Pair: data/train\images\294.tif <-> data/train\labels\294.png
# ✅ Pair: data/train\images\296.tif <-> data/train\labels\296.png
# ✅ Pair: data/train\images\297.tif <-> data/train\labels\297.png
# ✅ Pair: data/train\images\299.tif <-> data/train\labels\299.png
# ✅ Pair: data/train\images\3.tif <-> data/train\labels\3.png
# ✅ Pair: data/train\images\30.tif <-> data/train\labels\30.png
# ✅ Pair: data/train\images\300.tif <-> data/train\labels\300.png
# ✅ Pair: data/train\images\301.tif <-> data/train\labels\301.png
# ✅ Pair: data/train\images\302.tif <-> data/train\labels\302.png
# ✅ Pair: data/train\images\303.tif <-> data/train\labels\303.png
# ✅ Pair: data/train\images\305.tif <-> data/train\labels\305.png
# ✅ Pair: data/train\images\31.tif <-> data/train\labels\31.png
# ✅ Pair: data/train\images\32.tif <-> data/train\labels\32.png
# ✅ Pair: data/train\images\33.tif <-> data/train\labels\33.png
# ✅ Pair: data/train\images\34.tif <-> data/train\labels\34.png
# ✅ Pair: data/train\images\36.tif <-> data/train\labels\36.png
# ✅ Pair: data/train\images\37.tif <-> data/train\labels\37.png
# ✅ Pair: data/train\images\38.tif <-> data/train\labels\38.png
# ✅ Pair: data/train\images\39.tif <-> data/train\labels\39.png
# ✅ Pair: data/train\images\4.tif <-> data/train\labels\4.png
# ✅ Pair: data/train\images\40.tif <-> data/train\labels\40.png
# ✅ Pair: data/train\images\41.tif <-> data/train\labels\41.png
# ✅ Pair: data/train\images\42.tif <-> data/train\labels\42.png
# ✅ Pair: data/train\images\43.tif <-> data/train\labels\43.png
# ✅ Pair: data/train\images\44.tif <-> data/train\labels\44.png
# ✅ Pair: data/train\images\45.tif <-> data/train\labels\45.png
# ✅ Pair: data/train\images\46.tif <-> data/train\labels\46.png
# ✅ Pair: data/train\images\47.tif <-> data/train\labels\47.png
# ✅ Pair: data/train\images\48.tif <-> data/train\labels\48.png
# ✅ Pair: data/train\images\49.tif <-> data/train\labels\49.png
# ✅ Pair: data/train\images\5.tif <-> data/train\labels\5.png
# ✅ Pair: data/train\images\51.tif <-> data/train\labels\51.png
# ✅ Pair: data/train\images\52.tif <-> data/train\labels\52.png
# ✅ Pair: data/train\images\53.tif <-> data/train\labels\53.png
# ✅ Pair: data/train\images\55.tif <-> data/train\labels\55.png
# ✅ Pair: data/train\images\57.tif <-> data/train\labels\57.png
# ✅ Pair: data/train\images\58.tif <-> data/train\labels\58.png
# ✅ Pair: data/train\images\59.tif <-> data/train\labels\59.png
# ✅ Pair: data/train\images\6.tif <-> data/train\labels\6.png
# ✅ Pair: data/train\images\60.tif <-> data/train\labels\60.png
# ✅ Pair: data/train\images\61.tif <-> data/train\labels\61.png
# ✅ Pair: data/train\images\62.tif <-> data/train\labels\62.png
# ✅ Pair: data/train\images\63.tif <-> data/train\labels\63.png
# ✅ Pair: data/train\images\64.tif <-> data/train\labels\64.png
# ✅ Pair: data/train\images\65.tif <-> data/train\labels\65.png
# ✅ Pair: data/train\images\66.tif <-> data/train\labels\66.png
# ✅ Pair: data/train\images\67.tif <-> data/train\labels\67.png
# ✅ Pair: data/train\images\68.tif <-> data/train\labels\68.png
# ✅ Pair: data/train\images\69.tif <-> data/train\labels\69.png
# ✅ Pair: data/train\images\7.tif <-> data/train\labels\7.png
# ✅ Pair: data/train\images\70.tif <-> data/train\labels\70.png
# ✅ Pair: data/train\images\71.tif <-> data/train\labels\71.png
# ✅ Pair: data/train\images\72.tif <-> data/train\labels\72.png
# ✅ Pair: data/train\images\73.tif <-> data/train\labels\73.png
# ✅ Pair: data/train\images\74.tif <-> data/train\labels\74.png
# ✅ Pair: data/train\images\76.tif <-> data/train\labels\76.png
# ✅ Pair: data/train\images\77.tif <-> data/train\labels\77.png
# ✅ Pair: data/train\images\79.tif <-> data/train\labels\79.png
# ✅ Pair: data/train\images\8.tif <-> data/train\labels\8.png
# ✅ Pair: data/train\images\80.tif <-> data/train\labels\80.png
# ✅ Pair: data/train\images\81.tif <-> data/train\labels\81.png
# ✅ Pair: data/train\images\83.tif <-> data/train\labels\83.png
# ✅ Pair: data/train\images\84.tif <-> data/train\labels\84.png
# ✅ Pair: data/train\images\85.tif <-> data/train\labels\85.png
# ✅ Pair: data/train\images\86.tif <-> data/train\labels\86.png
# ✅ Pair: data/train\images\87.tif <-> data/train\labels\87.png
# ✅ Pair: data/train\images\89.tif <-> data/train\labels\89.png
# ✅ Pair: data/train\images\9.tif <-> data/train\labels\9.png
# ✅ Pair: data/train\images\91.tif <-> data/train\labels\91.png
# ✅ Pair: data/train\images\95.tif <-> data/train\labels\95.png
# ✅ Pair: data/train\images\96.tif <-> data/train\labels\96.png
# ✅ Pair: data/train\images\97.tif <-> data/train\labels\97.png
# ✅ Pair: data/train\images\98.tif <-> data/train\labels\98.png
# ✅ Pair: data/train\images\99.tif <-> data/train\labels\99.png
# Total pairs in data/train: 244
# Found 62 image files in data/val\images
# ✅ Pair: data/val\images\100.tif <-> data/val\labels\100.png
# ✅ Pair: data/val\images\109.tif <-> data/val\labels\109.png
# ✅ Pair: data/val\images\11.tif <-> data/val\labels\11.png
# ✅ Pair: data/val\images\111.tif <-> data/val\labels\111.png
# ✅ Pair: data/val\images\112.tif <-> data/val\labels\112.png
# ✅ Pair: data/val\images\116.tif <-> data/val\labels\116.png
# ✅ Pair: data/val\images\118.tif <-> data/val\labels\118.png
# ✅ Pair: data/val\images\119.tif <-> data/val\labels\119.png
# ✅ Pair: data/val\images\120.tif <-> data/val\labels\120.png
# ✅ Pair: data/val\images\13.tif <-> data/val\labels\13.png
# ✅ Pair: data/val\images\134.tif <-> data/val\labels\134.png
# ✅ Pair: data/val\images\138.tif <-> data/val\labels\138.png
# ✅ Pair: data/val\images\140.tif <-> data/val\labels\140.png
# ✅ Pair: data/val\images\142.tif <-> data/val\labels\142.png
# ✅ Pair: data/val\images\145.tif <-> data/val\labels\145.png
# ✅ Pair: data/val\images\15.tif <-> data/val\labels\15.png
# ✅ Pair: data/val\images\151.tif <-> data/val\labels\151.png
# ✅ Pair: data/val\images\155.tif <-> data/val\labels\155.png
# ✅ Pair: data/val\images\162.tif <-> data/val\labels\162.png
# ✅ Pair: data/val\images\17.tif <-> data/val\labels\17.png
# ✅ Pair: data/val\images\171.tif <-> data/val\labels\171.png
# ✅ Pair: data/val\images\186.tif <-> data/val\labels\186.png
# ✅ Pair: data/val\images\187.tif <-> data/val\labels\187.png
# ✅ Pair: data/val\images\19.tif <-> data/val\labels\19.png
# ✅ Pair: data/val\images\198.tif <-> data/val\labels\198.png
# ✅ Pair: data/val\images\199.tif <-> data/val\labels\199.png
# ✅ Pair: data/val\images\2.tif <-> data/val\labels\2.png
# ✅ Pair: data/val\images\200.tif <-> data/val\labels\200.png
# ✅ Pair: data/val\images\202.tif <-> data/val\labels\202.png
# ✅ Pair: data/val\images\205.tif <-> data/val\labels\205.png
# ✅ Pair: data/val\images\210.tif <-> data/val\labels\210.png
# ✅ Pair: data/val\images\22.tif <-> data/val\labels\22.png
# ✅ Pair: data/val\images\224.tif <-> data/val\labels\224.png
# ✅ Pair: data/val\images\226.tif <-> data/val\labels\226.png
# ✅ Pair: data/val\images\231.tif <-> data/val\labels\231.png
# ✅ Pair: data/val\images\233.tif <-> data/val\labels\233.png
# ✅ Pair: data/val\images\244.tif <-> data/val\labels\244.png
# ✅ Pair: data/val\images\253.tif <-> data/val\labels\253.png
# ✅ Pair: data/val\images\255.tif <-> data/val\labels\255.png
# ✅ Pair: data/val\images\257.tif <-> data/val\labels\257.png
# ✅ Pair: data/val\images\263.tif <-> data/val\labels\263.png
# ✅ Pair: data/val\images\265.tif <-> data/val\labels\265.png
# ✅ Pair: data/val\images\272.tif <-> data/val\labels\272.png
# ✅ Pair: data/val\images\273.tif <-> data/val\labels\273.png
# ✅ Pair: data/val\images\290.tif <-> data/val\labels\290.png
# ✅ Pair: data/val\images\291.tif <-> data/val\labels\291.png
# ✅ Pair: data/val\images\293.tif <-> data/val\labels\293.png
# ✅ Pair: data/val\images\295.tif <-> data/val\labels\295.png
# ✅ Pair: data/val\images\298.tif <-> data/val\labels\298.png
# ✅ Pair: data/val\images\304.tif <-> data/val\labels\304.png
# ✅ Pair: data/val\images\35.tif <-> data/val\labels\35.png
# ✅ Pair: data/val\images\50.tif <-> data/val\labels\50.png
# ✅ Pair: data/val\images\54.tif <-> data/val\labels\54.png
# ✅ Pair: data/val\images\56.tif <-> data/val\labels\56.png
# ✅ Pair: data/val\images\75.tif <-> data/val\labels\75.png
# ✅ Pair: data/val\images\78.tif <-> data/val\labels\78.png
# ✅ Pair: data/val\images\82.tif <-> data/val\labels\82.png
# ✅ Pair: data/val\images\88.tif <-> data/val\labels\88.png
# ✅ Pair: data/val\images\90.tif <-> data/val\labels\90.png
# ✅ Pair: data/val\images\92.tif <-> data/val\labels\92.png
# ✅ Pair: data/val\images\93.tif <-> data/val\labels\93.png
# ✅ Pair: data/val\images\94.tif <-> data/val\labels\94.png
# Total pairs in data/val: 62

# %%
print(f"Found {len(x_train)} training pairs and {len(x_val)} val pairs (guessed).")
# Out:
# Found 244 training pairs and 62 val pairs (guessed).

# %%
if CACHE_TO_NPY:
    out_train = os.path.join(TRAIN_DIR, 'cache')
    out_val = os.path.join(VAL_DIR, 'cache')
    os.makedirs(out_train, exist_ok=True)
    os.makedirs(out_val, exist_ok=True)
    print('Caching train...')
    for i,(x,y) in enumerate(zip(x_train,y_train)):
        arr = read_tif(x) # (bands,H,W)
        np.save(os.path.join(out_train, f"sample_{i:04d}_X.npy"), arr)
        mask = read_mask(y)
        np.save(os.path.join(out_train, f"sample_{i:04d}_Y.npy"), mask)
    print('Caching val...')
    for i,(x,y) in enumerate(zip(x_val,y_val)):
        arr = read_tif(x)
        np.save(os.path.join(out_val, f"sample_{i:04d}_X.npy"), arr)
        mask = read_mask(y)
        np.save(os.path.join(out_val, f"sample_{i:04d}_Y.npy"), mask)
    print('Cache finished')

# %%
import os
import matplotlib.pyplot as plt
import numpy as np
import tifffile
from PIL import Image

def display_image_and_mask(img_path, mask_path):
    # Read .tif image safely
    if img_path.lower().endswith(".tif"):
        img = tifffile.imread(img_path)  # works for multi-band tif
        # If multi-channel, take first 3 channels for visualization
        if img.ndim == 3 and img.shape[2] >= 3:
            img = img[:, :, :3]
    else:
        img = np.array(Image.open(img_path))

    # Read mask (usually png)
    mask = np.array(Image.open(mask_path))

    # Plot the image and the mask side by side
    fig, axs = plt.subplots(1, 2, figsize=(10, 5))
    axs[0].imshow(img)
    axs[0].set_title("Image")
    axs[0].axis("off")

    axs[1].imshow(mask, cmap="gray")
    axs[1].set_title("Mask")
    axs[1].axis("off")

    plt.show()

# %%
train_img_dir = r"data/train/images"
train_mask_dir = r"data/train/labels"

# Get image and mask filenames and sort them to ensure matching
train_img_files = sorted(os.listdir(train_img_dir))
train_mask_files = sorted(os.listdir(train_mask_dir))

# Check that the number of images matches the number of masks
if len(train_img_files) != len(train_mask_files):
    print("Error: The number of images and masks do not match!")
else:
    # Display only the first 5 image-mask pairs
    for img_file, mask_file in zip(train_img_files[:5], train_mask_files[:5]):
        # Construct the full file paths
        img_path = os.path.join(train_img_dir, img_file)
        mask_path = os.path.join(train_mask_dir, mask_file)
        # Display the image and mask together
        display_image_and_mask(img_path, mask_path)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-28..1099].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [23..1165].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-103..1109].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [67..1802].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [103..2556].

# %%
from albumentations import Compose, HorizontalFlip, VerticalFlip, RandomRotate90, ElasticTransform, GridDistortion, ShiftScaleRotate, RandomBrightnessContrast

def default_augmentations():
    return Compose([
    HorizontalFlip(p=0.5),
    VerticalFlip(p=0.5),
    RandomRotate90(p=0.5),
    ElasticTransform(p=0.2),
    GridDistortion(p=0.2),
    ShiftScaleRotate(shift_limit=0.1, scale_limit=0.2, rotate_limit=30, p=0.5),
    RandomBrightnessContrast(p=0.3),
    ])
# Out:
# INFO:albumentations.check_version:A new version of Albumentations is available: 2.0.8 (you have 1.4.10). Upgrade using: pip install --upgrade albumentations

# %%
class MultiSpectralTifDataset(Dataset):
    def __init__(self, x_paths, y_paths, transform=None, norm_mode="per_sample", cache=False):
        assert len(x_paths) == len(y_paths)
        self.x_paths = x_paths
        self.y_paths = y_paths
        self.transform = transform
        self.norm_mode = norm_mode
        self.cache = cache


    def __len__(self):
        return len(self.x_paths)


    def _normalize_per_sample(self, x):
        mean = x.mean(axis=(1,2), keepdims=True)
        std = x.std(axis=(1,2), keepdims=True)
        std[std==0] = 1.0
        return (x - mean) / std


    def _minmax_per_sample(self, x):
        mn = x.min(axis=(1,2), keepdims=True)
        mx = x.max(axis=(1,2), keepdims=True)
        rng = (mx - mn)
        rng[rng==0] = 1.0
        return (x - mn) / rng


    def __getitem__(self, idx):
        x_path = self.x_paths[idx]
        y_path = self.y_paths[idx]


        if x_path.lower().endswith('.npy'):
            x = np.load(x_path).astype(np.float32)
        else:
            x = read_tif(x_path).astype(np.float32)
        # ensure shape (bands,H,W)
        if x.ndim == 3 and x.shape[-1] == 12 and x.shape[0] != 12:
            x = np.transpose(x, (2,0,1))
        if x.ndim == 2:
            x = x[np.newaxis, ...]


        y = read_mask(y_path).astype(np.uint8)


        # Normalization
        if self.norm_mode == "per_sample":
            x = self._normalize_per_sample(x)
        elif self.norm_mode == "minmax":
            x = self._minmax_per_sample(x)
        elif self.norm_mode == "none":
            pass


        # Albumentations expects HWC
        if self.transform is not None:
            x_hwc = np.transpose(x, (1,2,0))
            augmented = self.transform(image=x_hwc, mask=y)
            x_hwc = augmented['image']
            y = augmented['mask']
            x = np.transpose(x_hwc, (2,0,1))


        x_t = torch.from_numpy(x).float()
        y_t = torch.from_numpy(y).long()
        return x_t, y_t

# %%
def show_band_grid(x_numpy, bands=None, figsize=(10,8), cmap='gray'):
    assert x_numpy.shape[0] >= 1
    n = x_numpy.shape[0]
    ncols = 4
    nrows = int(np.ceil(n / ncols))
    plt.figure(figsize=figsize)
    
    for i in range(n):
        plt.subplot(nrows, ncols, i+1)
        plt.imshow(x_numpy[i], cmap=cmap)
        title = f"B{i}" if bands is None else bands[i]
        plt.title(title)
        plt.axis('off')
        
    plt.tight_layout()
    plt.show()

# %%
from PIL import Image
from tensorflow.keras import layers, Model, Input

def unet_model(input_size=(128, 128, 3)):
    inputs = Input(input_size)

    # Encoder
    c1 = layers.Conv2D(64, (3, 3), activation='relu', padding='same')(inputs)
    c1 = layers.Conv2D(64, (3, 3), activation='relu', padding='same')(c1)
    p1 = layers.MaxPooling2D((2, 2))(c1)

    c2 = layers.Conv2D(128, (3, 3), activation='relu', padding='same')(p1)
    c2 = layers.Conv2D(128, (3, 3), activation='relu', padding='same')(c2)
    p2 = layers.MaxPooling2D((2, 2))(c2)

    c3 = layers.Conv2D(256, (3, 3), activation='relu', padding='same')(p2)
    c3 = layers.Conv2D(256, (3, 3), activation='relu', padding='same')(c3)
    p3 = layers.MaxPooling2D((2, 2))(c3)

    c4 = layers.Conv2D(512, (3, 3), activation='relu', padding='same')(p3)
    c4 = layers.Conv2D(512, (3, 3), activation='relu', padding='same')(c4)
    p4 = layers.MaxPooling2D((2, 2))(c4)

    c5 = layers.Conv2D(1024, (3, 3), activation='relu', padding='same')(p4)
    c5 = layers.Conv2D(1024, (3, 3), activation='relu', padding='same')(c5)


    # Decoder
    u6 = layers.Conv2DTranspose(512, (2, 2), strides=(2, 2), padding='same')(c5)
    u6 = layers.concatenate([u6, c4])
    c6 = layers.Conv2D(512, (3, 3), activation='relu', padding='same')(u6)
    c6 = layers.Conv2D(512, (3, 3), activation='relu', padding='same')(c6)

    u7 = layers.Conv2DTranspose(256, (2, 2), strides=(2, 2), padding='same')(c6)
    u7 = layers.concatenate([u7, c3])
    c7 = layers.Conv2D(256, (3, 3), activation='relu', padding='same')(u7)
    c7 = layers.Conv2D(256, (3, 3), activation='relu', padding='same')(c7)

    u8 = layers.Conv2DTranspose(128, (2, 2), strides=(2, 2), padding='same')(c7)
    u8 = layers.concatenate([u8, c2])
    c8 = layers.Conv2D(128, (3, 3), activation='relu', padding='same')(u8)
    c8 = layers.Conv2D(128, (3, 3), activation='relu', padding='same')(c8)

    u9 = layers.Conv2DTranspose(64, (2, 2), strides=(2, 2), padding='same')(c8)
    u9 = layers.concatenate([u9, c1])
    c9 = layers.Conv2D(64, (3, 3), activation='relu', padding='same')(u9)
    c9 = layers.Conv2D(64, (3, 3), activation='relu', padding='same')(c9)

    # Output layer
    outputs = layers.Conv2D(1, (1, 1), activation='sigmoid')(c9)

    model = Model(inputs=[inputs], outputs=[outputs])

    return model

# %%
from tensorflow.keras.utils import Sequence
import numpy as np
import tifffile
import cv2
import os

class TiffDataGenerator(Sequence):
    def __init__(self, img_dir, mask_dir, img_size=(128,128), batch_size=16):
        self.img_files = sorted(os.listdir(img_dir))
        self.mask_files = sorted(os.listdir(mask_dir))
        self.img_dir = img_dir
        self.mask_dir = mask_dir
        self.img_size = img_size
        self.batch_size = batch_size

    def __len__(self):
        return int(np.ceil(len(self.img_files) / self.batch_size))

    def __getitem__(self, idx):
        batch_x = self.img_files[idx*self.batch_size:(idx+1)*self.batch_size]
        batch_y = self.mask_files[idx*self.batch_size:(idx+1)*self.batch_size]

        imgs = []
        masks = []
        for img_file, mask_file in zip(batch_x, batch_y):
            # Load .tif image
            img = tifffile.imread(os.path.join(self.img_dir, img_file))
            img = cv2.resize(img, self.img_size)  # resize if needed
            img = img.astype(np.float32) / 255.0  # normalize

            # Load mask (png)
            mask = cv2.imread(os.path.join(self.mask_dir, mask_file), cv2.IMREAD_GRAYSCALE)
            mask = cv2.resize(mask, self.img_size)
            mask = (mask > 127).astype(np.float32)  # binarize 0/1
            mask = np.expand_dims(mask, axis=-1)   # add channel

            imgs.append(img)
            masks.append(mask)

        return np.array(imgs), np.array(masks)

# %%
model = unet_model(input_size=(128, 128, 12))
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
model.summary()



train_generator = TiffDataGenerator("data/train/images", "data/train/labels", img_size=(128,128), batch_size=16)
val_generator   = TiffDataGenerator("data/val/images", "data/val/labels", img_size=(128,128), batch_size=16)

model.fit(
    train_generator,
    validation_data=val_generator,
    epochs=5
)
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 128, 128,  │          0 │ -                 │
# │ (InputLayer)        │ 12)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d (Conv2D)     │ (None, 128, 128,  │      6,976 │ input_layer[0][0] │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_1 (Conv2D)   │ (None, 128, 128,  │     36,928 │ conv2d[0][0]      │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d       │ (None, 64, 64,    │          0 │ conv2d_1[0][0]    │
# │ (MaxPooling2D)      │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_2 (Conv2D)   │ (None, 64, 64,    │     73,856 │ max_pooling2d[0]… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_3 (Conv2D)   │ (None, 64, 64,    │    147,584 │ conv2d_2[0][0]    │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_1     │ (None, 32, 32,    │          0 │ conv2d_3[0][0]    │
# │ (MaxPooling2D)      │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_4 (Conv2D)   │ (None, 32, 32,    │    295,168 │ max_pooling2d_1[… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_5 (Conv2D)   │ (None, 32, 32,    │    590,080 │ conv2d_4[0][0]    │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_2     │ (None, 16, 16,    │          0 │ conv2d_5[0][0]    │
# │ (MaxPooling2D)      │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_6 (Conv2D)   │ (None, 16, 16,    │  1,180,160 │ max_pooling2d_2[… │
# │                     │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_7 (Conv2D)   │ (None, 16, 16,    │  2,359,808 │ conv2d_6[0][0]    │
# │                     │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_3     │ (None, 8, 8, 512) │          0 │ conv2d_7[0][0]    │
# │ (MaxPooling2D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_8 (Conv2D)   │ (None, 8, 8,      │  4,719,616 │ max_pooling2d_3[… │
# │                     │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_9 (Conv2D)   │ (None, 8, 8,      │  9,438,208 │ conv2d_8[0][0]    │
# │                     │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose    │ (None, 16, 16,    │  2,097,664 │ conv2d_9[0][0]    │
# │ (Conv2DTranspose)   │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate         │ (None, 16, 16,    │          0 │ conv2d_transpose… │
# │ (Concatenate)       │ 1024)             │            │ conv2d_7[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_10 (Conv2D)  │ (None, 16, 16,    │  4,719,104 │ concatenate[0][0] │
# │                     │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_11 (Conv2D)  │ (None, 16, 16,    │  2,359,808 │ conv2d_10[0][0]   │
# │                     │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_1  │ (None, 32, 32,    │    524,544 │ conv2d_11[0][0]   │
# │ (Conv2DTranspose)   │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_1       │ (None, 32, 32,    │          0 │ conv2d_transpose… │
# │ (Concatenate)       │ 512)              │            │ conv2d_5[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_12 (Conv2D)  │ (None, 32, 32,    │  1,179,904 │ concatenate_1[0]… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_13 (Conv2D)  │ (None, 32, 32,    │    590,080 │ conv2d_12[0][0]   │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_2  │ (None, 64, 64,    │    131,200 │ conv2d_13[0][0]   │
# │ (Conv2DTranspose)   │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_2       │ (None, 64, 64,    │          0 │ conv2d_transpose… │
# │ (Concatenate)       │ 256)              │            │ conv2d_3[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_14 (Conv2D)  │ (None, 64, 64,    │    295,040 │ concatenate_2[0]… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_15 (Conv2D)  │ (None, 64, 64,    │    147,584 │ conv2d_14[0][0]   │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_3  │ (None, 128, 128,  │     32,832 │ conv2d_15[0][0]   │
# │ (Conv2DTranspose)   │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_3       │ (None, 128, 128,  │          0 │ conv2d_transpose… │
# │ (Concatenate)       │ 128)              │            │ conv2d_1[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_16 (Conv2D)  │ (None, 128, 128,  │     73,792 │ concatenate_3[0]… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_17 (Conv2D)  │ (None, 128, 128,  │     36,928 │ conv2d_16[0][0]   │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_18 (Conv2D)  │ (None, 128, 128,  │         65 │ conv2d_17[0][0]   │
# │                     │ 1)                │            │                   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 31,036,929 (118.40 MB)
#  Trainable params: 31,036,929 (118.40 MB)
#  Non-trainable params: 0 (0.00 B)
# c:\Users\motaw\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/5
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 74s 4s/step - accuracy: 0.9394 - loss: 0.0590 - val_accuracy: 1.0000 - val_loss: 0.0000e+00
# Epoch 2/5
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 68s 4s/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.0000e+00
# Epoch 3/5
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 61s 4s/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.0000e+00
# Epoch 4/5
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 56s 4s/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.0000e+00
# Epoch 5/5
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 52s 3s/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.0000e+00

# %%
loss, accuracy = model.evaluate(val_generator, steps=50)
print(f'Validation Loss: {loss}')
print(f'Validation Accuracy: {accuracy}')

# %%
def overlay_predictions(model, generator, alpha=0.5, batch_idx=0):
    # Get one batch
    images, masks = generator[batch_idx]  

    # Run prediction
    predictions = model.predict(images)

    for i in range(len(images)):
        plt.figure(figsize=(12, 6))

        plt.subplot(1, 2, 1)
        plt.title("Input Image (first 3 bands)")
        plt.imshow(images[i][..., :3])  # only show RGB, since .tif has 12 bands
        plt.axis('off')

        plt.subplot(1, 2, 2)
        plt.title("Prediction Overlay")
        plt.imshow(images[i][..., :3])
        plt.imshow(predictions[i].squeeze(), cmap='jet', alpha=alpha)
        plt.axis('off')

        plt.show()

# %%
overlay_predictions(model, val_generator)
