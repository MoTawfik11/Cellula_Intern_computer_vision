# %%
from ultralytics import YOLO

# %%
import torch
print(torch.cuda.is_available())  # should be True
print(torch.cuda.get_device_name(0))  # should print GPU name
# Out:
# True
# NVIDIA GeForce RTX 4090 Laptop GPU

# %%
import torch
device = "cuda" if torch.cuda.is_available() else "cpu"
print("Using device:", device)
# Out:
# Using device: cuda

# %%
model = YOLO("yolov8n-cls.pt")

# %%
model.train(
    data="E:\\Computer Vision\\Cellula Tech\\Task 1\\Teeth_Dataset",    # Path to dataset folder
    epochs=200,               # Number of epochs (increase if needed)
    imgsz=224,               # Image size (224 is default for classification)
    batch=16,                # Adjust based on your GPU
    device=0 if device=="cuda" else "cpu",
    patience=10,             # Early stopping patience
)
# Out:
# Ultralytics 8.3.196  Python-3.10.18 torch-2.5.1+cu121 CUDA:0 (NVIDIA GeForce RTX 4090 Laptop GPU, 16376MiB)
# ...
